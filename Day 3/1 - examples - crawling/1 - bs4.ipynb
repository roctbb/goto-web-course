# %% [markdown]
# Предположим мы хотим составить датасет с рок-концертами в крупных городах в России за последние 20 лет. Например, чтобы выяснить, какая группа выступала чаще.
#
# Скорее всего, через API мы такую информацию не вытащим (хотя бы потому, что там точно нет данных до 2007 года), зато она есть на профильных сайтах, например, на https://darkside.ru/show/.
# Для начала научимся скачивать html код страницы.

# %%
import requests

answer = requests.get("https://darkside.ru/show/")
print(answer.text[:2000])
print("... и так далее")

# %% [markdown]
# Чтобы понять, правда ли мы скачали страницу с данными, а не страницу с ошибкой, можно посмотреть на код ответа. Если все хорошо - код ответа 200 (а если страница не найдена - 404).

# %%
print(answer.status_code)
# Out:
# 200

# %% [markdown]
# Для того, чтобы "вытягивать" нужную нам информацию из html кода, можно использовать библиотеку beautiful soup, она умеет строить дерево из тегов и производить поиск в нем.

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/roctbb/anaconda3/lib/python3.7/site-packages (4.6.3)

# %%
from bs4 import BeautifulSoup

document = BeautifulSoup(answer.text, 'html.parser')

# %% [markdown]
# Попробуем для начала найти все ссылки и выведем их на экран.

# %%
links = document.find_all('a')
for link in links[:20]:
    print(link, end='\n----\n')
# Out:
# <a name="top"><table border="0" cellpadding="0" cellspacing="0" height="162" width="100%"><tr valign="BOTTOM"><td align="center" background="/img/top-1-bg.png" height="24"><img height="1" src="/img/blank.gif" style="visibility:hidden" width="45"/></td><td align="center" background="/img/top-1-bg.png" height="24"><center><img height="24" src="/img/blank.gif" style="visibility:hidden" width="1"/><span id="menulayer0" onmouseout="initiateHideMenu(0); return true" onmouseover="showMenu(0); return true"><img border="0" height="24" src="/img/top-1-2-events.png" width="72"/></span><img border="0" height="24" src="/img/top-1-3.png" width="29"/><span id="menulayer1" onmouseout="initiateHideMenu(1); return true" onmouseover="showMenu(1); return true"><img border="0" height="24" src="/img/top-1-4-music.png" width="72"/></span><img border="0" height="24" src="/img/top-1-5.png" width="10"/><img border="0" height="24" src="/img/top-1-logo.jpg" width="427"/><img border="0" height="24" src="/img/top-1-7.png" width="10"/><span id="menulayer2" onmouseout="initiateHideMenu(2); return true" onmouseover="showMenu(2); return true"><img alt="Arts" border="0" height="24" src="/img/top-1-8-arts.png" width="72"/></span><img border="0" height="24" src="/img/top-1-9.png" width="29"/><span id="menulayer3" onmouseout="initiateHideMenu(3); return true" onmouseover="showMenu(3); return true"><img border="0" height="24" src="/img/top-1-10-comm.png" width="72"/></span></center></td></tr></table></a>
# ----
# <a href=" alt="ENG" border="0" height="12" hspace="5" src="/img/flag_en.gif" vspace="5" width="35"/></a>
# ----
# <a href="/forum/ucp.php?mode=login" onmouseout="initiateHideMenu(4); return true" onmouseover="showLoginMenu(4); return true"><img alt="LOGIN" border="0" height="16" hspace="10" src="/img/top-3-login.png" vspace="1" width="45"/></a>
# ----
# <a href="/forum/ucp.php?mode=register"><img alt="register" border="0" height="11" hspace="10" src="/img/icon-register.gif" vspace="0" width="39"/></a>
# ----
# <a href="/show/"><img alt="Концерты" border="0" height="28" src="/img/show-logo-1.jpg" width="179"/></a>
# ----
# <a href="/show/"><img alt="Концерты" border="0" height="84" src="/img/show-logo-2.jpg" width="179"/></a>
# ----
# <a href="/show/clubs/"><img alt="Клубы" border="0" height="9" hspace="15" onmouseout="this.src = '/img/show-topt-clubs_off.gif';" onmouseover="this.src = '/img/show-topt-clubs_on.gif';" src="/img/show-topt-clubs_off.gif" width="41"/></a>
# ----
# <a href="/show/promoters/"><img alt="Организаторы" border="0" height="9" hspace="10" onmouseout="this.src = '/img/show-topt-promoters_off.gif';" onmouseover="this.src = '/img/show-topt-promoters_on.gif';" src="/img/show-topt-promoters_off.gif" width="75"/></a>
# ----
# <a href="/show/towns/"><img alt="Города" border="0" height="9" hspace="15" onmouseout="this.src = '/img/show-topt-towns_off.gif';" onmouseover="this.src = '/img/show-topt-towns_on.gif';" src="/img/show-topt-towns_off.gif" width="44"/></a>
# ----
# <a href="/show/index.phtml?cp=9517"><img alt="<" border="0" height="18" src="/img/icon-arr-left.gif" width="14"/></a>
# ----
# <a href="/show/index.phtml?cp=0"><font color="#940D0D">1</font></a>
# ----
# <a href="/show/index.phtml?cp=9405"><font color="#940D0D">100</font></a>
# ----
# <a href="/show/index.phtml?cp=9500"><font color="#940D0D">101</font></a>
# ----
# <a href="#top"><img alt="/\\" border="0" height="14" hspace="5" src="/img/icon-arr-bbepx.gif" vspace="5" width="18"/><img alt="Вверх" border="0" height="17" src="/img/icon-bbepx.gif" vspace="0" width="52"/></a>
# ----
# <a href="/banners/go_bottom.phtml?id=1059"><img alt="Godspeed You! Black Emperor " border="0" src="/banners/bottom/1059-GIBE-2019-468x60.gif"/></a>
# ----
# <a href="<img alt="Рейтинг@" height="31" src="" style = "border:0;" width="88"/></a>
# ----
# <a href=" color="#650D0A"> 1997-2019 © Russian Darkside e-Zine.</font></a>
# ----
# <a href="/feedback/">сообщите нам об этом</a>
# ----
# <a href="<img alt="" border="0" height="1" src="" width = "1"/></a>
# ----
# <a href="/news/" onmouseout=".color='#C08A56';return true" onmouseover=".color='#F0A754';return true" style="color:#C08A56">Новости</a>
# ----

# %% [markdown]
# Как мы видим, среди ссылок есть нужные, но есть и много мусора. Попробуем отфильтровать ненужное: как минимум убрать ссылки с пустым текстом или без href.

# %%
links = document.find_all('a')
for link in links[:20]:
    if link.text == '':
        continue
    if 'href' not in link.attrs:
        continue
    print(link, end='\n----\n')
# Out:
# <a href="/show/index.phtml?cp=0"><font color="#940D0D">1</font></a>
# ----
# <a href="/show/index.phtml?cp=9405"><font color="#940D0D">100</font></a>
# ----
# <a href="/show/index.phtml?cp=9500"><font color="#940D0D">101</font></a>
# ----
# <a href="<img alt="Рейтинг@" height="31" src="" style = "border:0;" width="88"/></a>
# ----
# <a href=" color="#650D0A"> 1997-2019 © Russian Darkside e-Zine.</font></a>
# ----
# <a href="/feedback/">сообщите нам об этом</a>
# ----
# <a href="<img alt="" border="0" height="1" src="" width = "1"/></a>
# ----
# <a href="/news/" onmouseout=".color='#C08A56';return true" onmouseover=".color='#F0A754';return true" style="color:#C08A56">Новости</a>
# ----

# %% [markdown]
# Кажется, мы отобрали нужные строки. Теперь попробуем понять, что есть что. Например, на основе href.

# %%
for link in document.find_all('a'):
    if link.text == '':
        continue
    if 'href' not in link.attrs:
        continue
    if '/show/' not in link.attrs.get('href') or  '/show/' == link.attrs.get('href'):
        continue
    if '/show/index.phtml' in link.attrs.get('href'):
        continue
    if "club" in link.attrs.get('href'):
        print("Клуб", link.text)
    elif "town" in link.attrs.get('href'):
        print("Город", link.text)
    elif "promoter" in link.attrs.get('href'):
        print("Организатор", link.text)
    else:
        print('---' * 3)
        print("Группа", link.text)

# %% [markdown]
# Осталось сложить это все в датасет, скачав данные со всех страниц.

# %%
import pandas as pd

concerts = pd.DataFrame(columns=['band', 'town', 'club', 'promoter'])
i = 0
concert = {'club': '', 'promoter': '', 'band': '', 'town': ''}

for p in range(0, 90):
    print(".", end='')
    answer = requests.get(f' * 108}')
    document = BeautifulSoup(answer.text, 'html.parser')

    for link in document.find_all('a'):
        if link.text == '':
            continue
        if 'href' not in link.attrs:
            continue
        if '/show/' not in link.attrs.get('href') or  '/show/' == link.attrs.get('href'):
            continue
        if '/show/index.phtml' in link.attrs.get('href'):
            continue
        if "club" in link.attrs.get('href'):
            concert['club'] = link.text
        elif "town" in link.attrs.get('href'):
            concert['town'] = link.text
        elif "promoter" in link.attrs.get('href'):
            concert['promoter'] = link.text
        else:
            if concert['band'] != '':
                concerts.loc[i] = (concert['band'], concert['town'], concert['club'], concert['promoter'])
                i += 1
            concert = {'club': '', 'promoter': '', 'band': '', 'town': ''}
            concert['band'] = link.text
    concerts.loc[i]  = (concert['band'], concert['town'], concert['club'], concert['promoter'])
concerts
# Out:
# ..........................................................................................
#                                                     band             town  \
# 0                                                 Hatari           Москва
# 1                                             Guano Apes  Санкт-Петербург
# 2                                                   Saor           Москва
# 3                                                 Theory           Москва
# 4                                         Чёрный Обелиск           Москва
# 5                                             Guano Apes           Москва
# 6                                    Motionless In White           Москва
# 7                                    Motionless In White  Санкт-Петербург
# 8                                              Weedeater  Санкт-Петербург
# 9                                                      1
# 10                                             Weedeater           Москва
# 11                                           Combichrist           Москва
# 12                                           Combichrist  Санкт-Петербург
# 13                                                 Boris           Москва
# 14                                                 Boris  Санкт-Петербург
# 15                           Godspeed You! Black Emperor  Санкт-Петербург
# 16                                              King 810           Москва
# 17                          Godspeed You! Black Emperor            Москва
# 18                                              King 810  Санкт-Петербург
# 19                                 The Devil Wears Prada           Москва
# 20                                             Ost+Front           Москва
# 21                                    Position ParallèLe  Санкт-Петербург
# 22                                      Beyond the Black  Санкт-Петербург
# 23                                                     1
# 24                                             Ost+Front  Санкт-Петербург
# 25                                    Position ParallèLe           Москва
# 26                                      Beyond The Black           Москва
# 27                                   Кипелов с оркестром  Санкт-Петербург
# 28                                  Pagan Reign, Ramchat           Москва
# 29                                 The Devil Wears Prada  Санкт-Петербург
# ...                                                  ...              ...
# 10305                           Концерт Nightwish (фото)           Москва
# 10306                       Концерт Mayhem (отчет, фото)           Москва
# 10307                       Концерт Glenn Hughes (отчет)           Москва
# 10308                               Концерт Glenn Hughes  Санкт-Петербург
# 10309  Международный фестиваль индустриальной музыки ...  Санкт-Петербург
# 10310                         Концерт To/Die/For (отчет)           Москва
# 10311                                 Концерт To/Die/For  Санкт-Петербург
# 10312                    Концерт Moonspell (отчет, фото)           Москва
# 10313                                     Концерт Тиамат           Москва
# 10314                         Концерт RAGE (отчет, фото)
# 10315                                                  1
# 10316                    Фестиваль "Бульdozer N2" (фото)  Санкт-Петербург
# 10317      Международный фестиваль "Молот и Гром" (фото)           Москва
# 10318    Фестиваль Wave-Gotik-Treffen 2002 (отчет, фото)
# 10319               Концерт Blind Guardian (отчет, фото)           Москва
# 10320           Концерт Theatre of Tragedy (отчет, фото)           Москва
# 10321                  Концерт группы ДЫХАНИЕ (darkwave)           Москва
# 10322         Готческая вечеринка The CRYPT Gothic Party           Москва
# 10323     Концерт группы CAPRICE (ethereal / neoclassic)           Москва
# 10324                                  Концерт Rammstein  Санкт-Петербург
# 10325                        Концерт Rammstein [отменен]           Москва
# 10326                                     Bang Your Head
# 10327                    Фестиваль LONG LIVE ROCK'N'ROLL           Москва
# 10328            gothic_dot_ru party (gothic/industrial)           Москва
# 10329                               Hammermusic Fest - 3
# 10330                                    Концерт Garbage  Санкт-Петербург
# 10331                                    Концерт Garbage           Москва
# 10332  Фестивале Современной Фольклорной Музыки "Алат...           Москва
# 10333                                The Smash Fest 2002
# 10334  Всемосковский Панк Фестиваль (Атака Клоунов: Р...           Москва
#
#                                        club                 promoter
# 0                               Клуб Театръ  Russian Synth Community
# 1                               Aurora Hall     Delta Mekong Concert
# 2                                    Pravda           Ritual Booking
# 3                                      1930                 Мельница
# 4                                  Red Club
# 5                        Adrenaline Stadium                 JC Sound
# 6      ГлавClub GreenConcert (ex-YotaSpace)     SPIKA Concert Agency
# 7                                       Zal     SPIKA Concert Agency
# 8                                       MOD        MadStream Booking
# 9
# 10                                Aglomerat        MadStream Booking
# 11                                 Red Club     Delta Mekong Concert
# 12                                      Zal         Infinity Concert
# 13                                Aglomerat        MadStream Booking
# 14                                      Zal        MadStream Booking
# 15                              Aurora Hall         Infinity Concert
# 16                                Aglomerat     SPIKA Concert Agency
# 17                                     1930     Delta Mekong Concert
# 18                                      Zal     SPIKA Concert Agency
# 19                                   Pravda             Play It Loud
# 20                          Клуб Rock House              Kultprodukt
# 21                                   Сердце           Ritual Booking
# 22                                      Zal     SPIKA Concert Agency
# 23
# 24                    Action (ex-Backstage)              Kultprodukt
# 25                                     Шаги           Ritual Booking
# 26                                Aglomerat     SPIKA Concert Agency
# 27                           Ледовый Дворец                 Мельница
# 28                                    Город     Delta Mekong Concert
# 29                                      MOD             Play It Loud
# ...                                     ...                      ...
# 10305
# 10306
# 10307
# 10308
# 10309
# 10310
# 10311
# 10312
# 10313
# 10314
# 10315
# 10316
# 10317
# 10318
# 10319
# 10320
# 10321
# 10322
# 10323
# 10324
# 10325
# 10326
# 10327
# 10328
# 10329
# 10330
# 10331
# 10332
# 10333
# 10334
#
# [10335 rows x 4 columns]

# %%
print(len(concerts))
# Out:
# 10335

# %% [markdown]
# Теперь можем даже посчитать, кто выступал чаще. А еще встречаются странные числа...
#
# Данные выше в приципе можно дополнительно почитстить, например, разделить группы на фестивалях, убрать слово концерт.

# %%
pd.value_counts(concerts['band'])[:30]
# Out:
# 1                  648
# 2                  300
# 3                  184
# 4                  141
# 5                   94
# 6                   76
# Эпидемия            55
# 7                   55
# 8                   47
# 9                   42
# 10                  39
# 13                  29
# Мельница            29
# 11                  27
# Ария                27
# Lacrimosa           25
# 12                  25
# 14                  23
# U.D.O.              21
# Papa Roach          20
# Scorpions           19
# Kreator             18
# Кипелов             18
# Accept              17
# Тролль Гнет Ель     17
# W.A.S.P.            17
# 15                  16
# Tarja Turunen       16
# 16                  16
# Anathema            15
# Name: band, dtype: int64
